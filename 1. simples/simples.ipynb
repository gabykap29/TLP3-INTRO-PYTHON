# %% [markdown]
# ## String en python 'str'
#
# Metodos mas utilizados son:
# * len(string)
# * str.upper()
# * str.lower()
# * str.strip()
# * str.split()

# %%
mi_str = "Hola, Mundo!"
mi_str.split(",")
# Out:
# ['Hola', ' Mundo!']

# %% [markdown]
# ## 'int', ENTEROS

# %%
mi_int = 545
type(mi_int)
# Out:
# int

# %% [markdown]
# ## 'float', DECIMALES

# %%
mi_float = 2.4
type(mi_float)
# Out:
# float

# %% [markdown]
# ## 'bool', BOOLEANOS

# %%
mi_bool = True
mi_bool = False
type(mi_bool)
# Out:
# bool

# %% [markdown]
# ## NONE - representa el valor nulo

# %%
mi_none = None
type(mi_none)
# Out:
# NoneType
